# %% [markdown]
# # Part 2 of the IBM Capstone Project: Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# By Tobias Mehra

# %% [markdown]
# ## Step 1: Get geo Data

# %%
# I tried using geocoder but it would not work so I am using the CSV file provided
import pandas as pd
# use pandas read function to convert file to dataframe
geo_data_df = pd.read_csv("https://cocl.us/Geospatial_data")
geo_data_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ## Import Toronto CSV file

# %%
# same as above with the csv file created in part 1 of this exercise

toronto_df = pd.read_csv("toronto_base.csv")
toronto_df.head()
# Out:
#    Unnamed: 0 Postal Code           Borough                    Neighbourhood
# 0           0         M3J        North York  Northwood Park, York University
# 1           1         M5C  Downtown Toronto                   St. James Town
# 2           2         M4L      East Toronto                     India Bazaar
# 3           3         M2M        North York          Newtonbrook, Willowdale
# 4           4         M1B       Scarborough                   Rouge, Malvern

# %% [markdown]
# ## Merge the 2 files

# %%
# Merge two dataframes along the Postal Code using pandas merge function 

df_toronto_geo = pd.merge(toronto_df, geo_data_df, on="Postal Code")
df_toronto_geo.to_csv("toronto_geo.csv")
df_toronto_geo.head(10)
# Out:
#    Unnamed: 0 Postal Code           Borough  \
# 0           0         M3J        North York
# 1           1         M5C  Downtown Toronto
# 2           2         M4L      East Toronto
# 3           3         M2M        North York
# 4           4         M1B       Scarborough
# 5           5         M3A        North York
# 6           6         M6L        North York
# 7           7         M6P      West Toronto
# 8           8         M6M              York
# 9           9         M6H      West Toronto
#
#                            Neighbourhood   Latitude  Longitude
# 0        Northwood Park, York University  43.767980 -79.487262
# 1                         St. James Town  43.651494 -79.375418
# 2                           India Bazaar  43.668999 -79.315572
# 3                Newtonbrook, Willowdale  43.789053 -79.408493
# 4                         Rouge, Malvern  43.806686 -79.194353
# 5                              Parkwoods  43.753259 -79.329656
# ...

# %% [markdown]
# Thanks for reviewing!
